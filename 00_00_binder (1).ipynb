# %% [markdown]
# # Páginas para programar python

# %% [markdown]
# 1. www.mybinder.org
# 2. www.kaggle.com
# 3. www.jupyter.org/try
# 4. `github jobish` https://mybinder.org/v2/gh/jobish03/jobish03-Visualizacion_de_datos_para_la_toma_de_decisiones/main?filepath=welcome_binder.ipynb
#
# Los paquetes hay que incluir en el archivo `requirements.txt`

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Fortnite_players_stats.csv')
df.head()
# Out:
#              Player  Solo score  Solo top1  Solo kd  Solo winRatio  \
# 0        Prospеring     2476763       1828     4.37           18.0
# 1        BH nixxxay      439562       1694     8.71           29.1
# 2            Raпger     4519465       4582     9.60           34.0
# 3            Idk_Pi      752869        121     0.84            3.3
# 4  Twitch.GryphonRB     1136282       1327     6.32           30.0
#
#    Solo matches  Solo kills  Solo minutesPlayed  Duos score  Duos top1  ...  \
# 0         10150       36328               81389     4702684       5584  ...
# 1          5817       35895               12732     4065613       4141  ...
# 2         13488       85481              122171     1137279       1390  ...
# 3          3687        3005               32453     5326457       2249  ...
# 4          4429       19591               36245     3692623       5743  ...
#
#    Squads kills  Squads minutesPlayed  LTM score  LTM top1  LTM top3  LTM kd  \
# ...

# %% [markdown]
# # Descripcion de base de datos
# ## Esta es una base de datos sobre 1500 jugadores del juego fortnite que juegan en pc

# %%
df.columns
# Out:
# Index(['Player', 'Solo score', 'Solo top1', 'Solo kd', 'Solo winRatio',
#        'Solo matches', 'Solo kills', 'Solo minutesPlayed', 'Duos score',
#        'Duos top1', 'Duos kd', 'Duos winRatio', 'Duos matches', 'Duos kills',
#        'Duos minutesPlayed', 'Trios score', 'Trios top1', 'Trios kd',
#        'Trios winRatio', 'Trios matches', 'Trios kills', 'Trios minutesPlayed',
#        'Squads score', 'Squads top1', 'Squads kd', 'Squads winRatio',
#        'Squads matches', 'Squads kills', 'Squads minutesPlayed', 'LTM score',
#        'LTM top1', 'LTM top3', 'LTM kd', 'LTM winRatio', 'LTM matches',
#        'LTM kills', 'LTM minutesPlayed'],
#       dtype='object')

# %%
df.drop(['LTM score',
       'LTM top1', 'LTM top3', 'LTM kd', 'LTM winRatio', 'LTM matches',
       'LTM kills', 'LTM minutesPlayed'],axis=1,inplace= True)

# %%
df.columns
# Out:
# Index(['Player', 'Solo score', 'Solo top1', 'Solo kd', 'Solo winRatio',
#        'Solo matches', 'Solo kills', 'Solo minutesPlayed', 'Duos score',
#        'Duos top1', 'Duos kd', 'Duos winRatio', 'Duos matches', 'Duos kills',
#        'Duos minutesPlayed', 'Trios score', 'Trios top1', 'Trios kd',
#        'Trios winRatio', 'Trios matches', 'Trios kills', 'Trios minutesPlayed',
#        'Squads score', 'Squads top1', 'Squads kd', 'Squads winRatio',
#        'Squads matches', 'Squads kills', 'Squads minutesPlayed'],
#       dtype='object')

# %%
df.shape
# Out:
# (1435, 29)

# %%
df.head()
# Out:
#              Player  Solo score  Solo top1  Solo kd  Solo winRatio  \
# 0        Prospеring     2476763       1828     4.37           18.0
# 1        BH nixxxay      439562       1694     8.71           29.1
# 2            Raпger     4519465       4582     9.60           34.0
# 3            Idk_Pi      752869        121     0.84            3.3
# 4  Twitch.GryphonRB     1136282       1327     6.32           30.0
#
#    Solo matches  Solo kills  Solo minutesPlayed  Duos score  Duos top1  ...  \
# 0         10150       36328               81389     4702684       5584  ...
# 1          5817       35895               12732     4065613       4141  ...
# 2         13488       85481              122171     1137279       1390  ...
# 3          3687        3005               32453     5326457       2249  ...
# 4          4429       19591               36245     3692623       5743  ...
#
#    Trios matches  Trios kills  Trios minutesPlayed  Squads score  Squads top1  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Pregunta 1
# ### Hay una relacion entre minutos jugados y victorias en el modo de juego solo?

# %%
sns.lmplot(x = 'Solo minutesPlayed',
           y = 'Solo top1',
           data = df,
           fit_reg=True)

# %% [markdown]
# # Pregunta 2
# ### Tiene que ver el numero de partidas jugadas en squads con el porcentaje de victorias?

# %%
sns.lmplot(x = 'Squads matches',
           y = 'Squads winRatio',
           data = df,
           fit_reg=False)

# %% [markdown]
# # Pregunta 3
# ## Que cantidad de victorias es lo mas comun que tengan los jugadores de pc

# %%
from matplotlib.pyplot import figure
figure(figsize=(30,8),dpi=80)
plt.subplot(1,3,1)
plt.hist('Solo top1', bins=9,data = df, color = 'r')

plt.xlabel('Solo Wins')
plt.ylabel('Frecuencia')
plt.title('Solo')
plt.subplot(1,3,2)
plt.hist('Duos top1', bins=7,data = df,color= 'm')

plt.xlabel('Duos Wins')
plt.ylabel('Frecuencia')
plt.title('Duos')
plt.subplot(1,3,3)
plt.hist('Squads top1', bins=10,data = df, color= 'k')

plt.xlabel('Squads Wins')
plt.ylabel('Frecuencia')
plt.title('Squads')
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# # Pregunta 4
# ## Que promedio de kills se tiene por partida en el modo de juego solo?

# %% [markdown]
# # Pregunta 5
# ## Quien es el jugador con mas victorias en los modos de juego solo,duos y squads, como este se compara con la media?

# %%
pivotw = pd.pivot_table(df, 
                        index= 'Player',
                        values='Solo top1',
                        aggfunc='max')

# %%
pivotw
# Out:
#                   Solo top1
# Player
# 00LaPlume                 5
# 05 ToyseTe               15
# 100T MrSalsiccia        209
# 101shanks                70
# 10ironhead00            321
# ...                     ...
# 사퍼드와이트                   13
# ＫＯ ＡＢＯ ＴＩＭ               29
# Ｌ３ＮＮ                    171
# ＷΛＬＫΞＲ                  126
# ｲﾘムﾑ                     32
#
# [1435 rows x 1 columns]
